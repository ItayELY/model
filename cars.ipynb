# %%
# %cd C:\Users\itaye\Desktop\pdexplain\pd-explain\src
import pandas as pd
import pd_explain
from IPython.display import FileLink, display, Image, IFrame, display_pdf, HTML
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pd_explain
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\itaye\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# C:\Users\itaye\Desktop\pdexplain\pd-explain\src
# C:\Users\itaye\AppData\Local\Temp\ipykernel_22196\4004644252.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# usetex-False

# %%
auto_df = pd.read_csv('C:/Users/itaye/Desktop/research_notes/notebooks/auto-mpg.csv')

# %%
auto_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto_df['hp'] = auto_df['horsepower'].apply(lambda x: int(x) if x.isdigit() else np.nan)

# %%
auto_df.plot.scatter(x='hp', y='acceleration')
# Out:
# <Axes: xlabel='hp', ylabel='acceleration'>

# %%
auto_df.plot.scatter(y='acceleration', x='mpg')
# Out:
# <Axes: xlabel='mpg', ylabel='acceleration'>

# %%
high_cylinders = auto_df[auto_df['cylinders'] > 4] 
high_cylinders.plot.scatter(y='acceleration', x='mpg')
# Out:
# <Axes: xlabel='mpg', ylabel='acceleration'>

# %%
high_cylinders.explain(top_k = 4)
# auto_df.groupby('cylinders').explain(top_k = 4)

# %%
low_mpg = auto_df[auto_df['mpg'] < 23]
low_mpg.explain(top_k = 3)
