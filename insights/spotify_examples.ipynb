# %%
# %cd C:\Users\itaye\Desktop\pdexplain\pd-explain\src
import pandas as pd
import pd_explain
from IPython.display import FileLink, display, Image, IFrame, display_pdf, HTML
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pd_explain
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\itaye\Desktop\pdexplain\pd-explain\src

# %%
all_songs = pd.read_csv('C:/Users/itaye/Desktop/pdexplain/pd-explain/Examples/Datasets/spotify_all.csv')
all_songs = all_songs[all_songs['popularity'] > 0]

# %%
all_songs.head()
# Out:
#    acousticness                    artists  danceability  energy  explicit  \
# 0      0.991000            ['Mamie Smith']         0.598   0.224         0
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852   0.517         0
# 2      0.993000            ['Mamie Smith']         0.647   0.186         0
# 3      0.000173        ['Oscar Velazquez']         0.730   0.798         0
# 4      0.295000                   ['Mixe']         0.704   0.707         1
#
#                        id  instrumentalness  key  liveness  loudness  ...  \
# 0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790   -12.628  ...
# 1  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809    -7.261  ...
# 2  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190   -12.098  ...
# 3  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280    -7.311  ...
# 4  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020    -6.036  ...
#
# ...

# %%
all_songs.select_dtypes(include=['int64', 'float64']).corr()
# Out:
#                   acousticness  danceability    energy  explicit  \
# acousticness          1.000000     -0.236959 -0.755785 -0.206778
# danceability         -0.236959      1.000000  0.200764  0.197012
# energy               -0.755785      0.200764  1.000000  0.165359
# explicit             -0.206778      0.197012  0.165359  1.000000
# instrumentalness      0.214581     -0.240146 -0.189110 -0.101542
# key                  -0.033807      0.030266  0.033847  0.013122
# liveness             -0.051528     -0.119501  0.161743  0.022245
# loudness             -0.582726      0.267039  0.778739  0.196928
# mode                  0.068125     -0.051803 -0.056414 -0.074993
# popularity           -0.367147      0.180941  0.278501  0.261971
# speechiness          -0.049537      0.189452  0.038006  0.260736
# tempo                -0.199763     -0.042394  0.244692  0.007158
# valence              -0.221386      0.548893  0.373023 -0.024746
# ...

# %%
quiet = all_songs[all_songs['loudness'] < -19]

# %%
quiet.select_dtypes(include=['int64', 'float64']).corr()
# Out:
#                   acousticness  danceability    energy  explicit  \
# acousticness          1.000000     -0.271164 -0.444264 -0.109057
# danceability         -0.271164      1.000000  0.186175  0.105573
# energy               -0.444264      0.186175  1.000000  0.134437
# explicit             -0.109057      0.105573  0.134437  1.000000
# instrumentalness      0.289580     -0.271819 -0.090213 -0.098699
# key                  -0.064144      0.061111  0.033081  0.025880
# liveness             -0.157428      0.042524  0.322719  0.211925
# loudness             -0.173171      0.288013  0.378143  0.030975
# mode                  0.040840     -0.025671 -0.030723 -0.001231
# popularity           -0.019392     -0.232853 -0.016114 -0.006921
# speechiness          -0.393274      0.443924  0.213976  0.242744
# tempo                -0.076942      0.135697  0.115652 -0.008032
# valence              -0.151640      0.555713  0.367353  0.071410
# ...

# %%
(quiet.select_dtypes(include=['int64', 'float64']).corr() * all_songs.select_dtypes(include=['int64', 'float64']).corr())# * all_songs.select_dtypes(include=['int64', 'float64']).corr()
# Out:
#                   acousticness  danceability    energy  explicit  \
# acousticness          1.000000      0.064255  0.335768  0.022551
# danceability          0.064255      1.000000  0.037377  0.020799
# energy                0.335768      0.037377  1.000000  0.022230
# explicit              0.022551      0.020799  0.022230  1.000000
# instrumentalness      0.062138      0.065276  0.017060  0.010022
# key                   0.002169      0.001850  0.001120  0.000340
# liveness              0.008112     -0.005082  0.052197  0.004714
# loudness              0.100911      0.076911  0.294475  0.006100
# mode                  0.002782      0.001330  0.001733  0.000092
# popularity            0.007120     -0.042133 -0.004488 -0.001813
# speechiness           0.019482      0.084102  0.008132  0.063292
# tempo                 0.015370     -0.005753  0.028299 -0.000057
# valence               0.033571      0.305027  0.137031 -0.001767
# ...

# %%
def bin(df, attr, n_bins = 10):
    _, bins = pd.cut(df[attr], bins=n_bins, retbins=True)
    x = pd.cut(df[attr], bins=bins)
    return x

# %%
# all_songs['loudness'] = bin(all_songs, 'loudness')
# all_songs['danceability'] = bin(all_songs, 'danceability')
# all_songs['acousticness'] = bin(all_songs, 'acousticness')
all_songs['energy'] = bin(all_songs, 'energy')

# %%
popular = all_songs[all_songs.popularity >= 50]

# %%
popular.groupby('loudness').acousticness.mean().plot()
# Out:
# <Axes: xlabel='loudness'>

# %%
instrumental = all_songs[all_songs['instrumentalness'] > 0.7]
instrumental.groupby('loudness').acousticness.mean().plot()
# Out:
# <Axes: xlabel='loudness'>

# %%
old = all_songs[all_songs.year <= 1960]
old.groupby('loudness').acousticness.mean().plot()
# Out:
# <Axes: xlabel='loudness'>

# %%
energetic = all_songs[all_songs['explicit'] == 1]
energetic.groupby('loudness').acousticness.mean().plot()
# Out:
# <Axes: xlabel='loudness'>

# %%
energetic = all_songs[all_songs['liveness'] >= 0.5]
energetic.groupby('loudness').acousticness.mean().plot()
# Out:
# <Axes: xlabel='loudness'>

# %%
all_songs.groupby('year').loudness.mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
non_explicit = all_songs[all_songs['explicit'] == 0]
non_explicit.groupby('year').popularity.mean().plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# # energy - popularity

# %%
# all_songs.groupby('energy').popularity.count().plot()
all_songs.plot.scatter(x='instrumentalness', y='acousticness', grid=True, c='decade', colormap='viridis')
# Out:
# <Axes: xlabel='instrumentalness', ylabel='acousticness'>

# %%
new = all_songs[all_songs['valence'] <= 0.5]
new.plot.scatter(x='loudness', y='acousticness', grid=True, c='explicit', colormap='viridis')
# new.groupby('energy').popularity.count().
# Out:
# <Axes: xlabel='loudness', ylabel='acousticness'>

# %%
new = all_songs[all_songs['year'] > 1970]
popular.plot.scatter(x='loudness', y='instrumentalness', grid=True, c='explicit', colormap='viridis')
# new.groupby('loudness').popularity.count().plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[192], line 2
#       1 new = all_songs[all_songs['year'] > 1970]
# ----> 2 popular.plot.scatter(x='loudness', y='instrumentalness', grid=True, c='explicit', colormap='viridis')
#       3 # new.groupby('loudness').popularity.count().plot()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\plotting\_core.py:1748, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1660 def scatter(
#    1661     self,
#    1662     x: Hashable,
#    (...)
#    1666     **kwargs,
#    1667 ) -> PlotAccessor:
#    1668     """
#    1669     Create a scatter plot with varying marker point size and color.
#    1670
#    (...)
#    1746         ...                       colormap='viridis')
#    1747     """
# ...
